# %% [markdown]
# # This Notebook Aims to Use the KNN Regression Method

# %% [markdown]
# ## Importing

# %%
from pathlib import Path
import sys
root= Path.cwd().parent
sys.path.append(str(root))
from src.regression import KNN_regression_tuning
from src.graph import K_MSE
import pandas as pd

# %%
training_data = pd.read_csv("../data/processed/training_data.csv")
testing_data = pd.read_csv("../data/processed/testing_data.csv")

# %% [markdown]
# Separate the predictors and the targets

# %%
training_data= pd.concat([ training_data.iloc[:, 0:3], training_data.iloc[:, 4:]], axis=1 )
training_targets = training_data.iloc[:, 3]

testing_data= pd.concat( [testing_data.iloc[:, 0:3], testing_data.iloc[:, 4:]], axis=1 )
testing_targets = testing_data.iloc[:, 3]

# %% [markdown]
# ## Testing Different K values And Visualizing the MSE

# %%
training_MSE = KNN_regression_tuning( range(1,101, 2), training_data, training_targets, training_data, training_targets )
# Out:
# iteration: k=1
# iteration: k=3
# iteration: k=5
# iteration: k=7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 training_MSE = KNN_regression_tuning( range(1,101, 2), training_data, training_targets, training_data, training_targets )
#
# File c:\Users\PC\Documents\House Prediction Project\src\regression.py:193, in KNN_regression_tuning(k_range, training_dataset, training_targets, testing_dataset, testing_targets)
#     191 print(f'iteration: k={k}')
#     192 #predict
# --> 193 predictions = KNN_prediction(k, training_dataset, training_targets, testing_dataset)
#     194 #calculate the MSE
#     195 K_MSE[k] = MSE(testing_targets, predictions)
#
# File c:\Users\PC\Documents\House Prediction Project\src\regression.py:173, in KNN_prediction(k, dataset, targets, testing_dataset)
#     171 predictions = np.zeros(len(testing_dataset))
#     172 for i, row in enumerate(testing_dataset):
# --> 173     t = K_nearest_neighbors(k, dataset, targets, row)
#     174     predictions[i]= t
#     175 return predictions
#
# File c:\Users\PC\Documents\House Prediction Project\src\regression.py:154, in K_nearest_neighbors(k, dataset, targets, point)
#     152 #euclidean distance
#     153 distances = np.linalg.norm(dataset - point, axis=1)
# --> 154 closest_indices = np.argpartition(distances, k)[:k]
#     155 neighbors_targets = targets[closest_indices]
#     156 return neighbors_targets.mean()
#
# File c:\Users\PC\anaconda3\Lib\site-packages\numpy\_core\fromnumeric.py:961, in argpartition(a, kth, axis, kind, order)
#     875 @array_function_dispatch(_argpartition_dispatcher)
#     876 def argpartition(a, kth, axis=-1, kind='introselect', order=None):
#     877     """
#     878     Perform an indirect partition along the given axis using the
#     879     algorithm specified by the `kind` keyword. It returns an array of
#    (...)    959
#     960     """
# --> 961     return _wrapfunc(a, 'argpartition', kth, axis=axis, kind=kind, order=order)
#
# File c:\Users\PC\anaconda3\Lib\site-packages\numpy\_core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)     64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:
