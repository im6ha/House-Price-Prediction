# %% [markdown]
# # This Notebook Aims to Use Polynomial Regression

# %% [markdown]
# ## Importing

# %%
from pathlib import Path
import sys
root= Path.cwd().parent
sys.path.append(str(root))
from src.regression import polynomial_regression, R_Square, adjusted_r2, aic, bic
from src.graph import polynomial_regression_graph
import pandas as pd

# %%
training_data = pd.read_csv("../data/processed/training_data.csv")
testing_data = pd.read_csv("../data/processed/testing_data.csv")
training_X= pd.concat([training_data.iloc[:, 0:3], training_data.iloc[:, 4:]], axis=1 )
training_y= training_data.iloc[:, 3]
testing_X= pd.concat([testing_data.iloc[:, 0:3], testing_data.iloc[:, 4:]], axis=1 )
testing_y= testing_data.iloc[:, 3]

# %%
training_X.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'bedrooms_per_room',
#        'population_per_household', 'rooms_per_household', 'log_total_rooms',
#        'log_total_bedrooms', 'log_population', 'log_households',
#        'log_median_income', '<1h ocean', 'inland', 'near ocean', 'island'],
#       dtype='object')

# %% [markdown]
# ## Polynomial Regression

# %% [markdown]
# Testing from d=1 (regular linear regression) to d=4

# %%
training_X.describe()
# Out:
#           longitude      latitude  housing_median_age  bedrooms_per_room  \
# count  16512.000000  16512.000000        16512.000000       16512.000000
# mean       0.218892     -0.176783            0.050679           0.044389
# std        0.959699      0.976916            1.016190           1.029599
# min       -2.385935     -1.447533           -2.196127          -2.627282
# 25%       -0.833676     -0.824860           -0.765917          -0.567013
# 50%        0.633733     -0.717180            0.108101          -0.120829
# 75%        0.838372      0.963569            0.743750           0.463170
# max        2.625216      2.957996            1.856137          40.014629
#
#        population_per_household  rooms_per_household  log_total_rooms  \
# count              16512.000000         16512.000000     16512.000000
# mean                  -0.006042            -0.013940        -0.003547
# std                    0.494226             1.073810         0.995616
# ...

# %%
results = polynomial_regression(training_X, training_y, testing_X, testing_y, range(1, 5), [adjusted_r2])
# Out:
# c:\Users\PC\Documents\House Prediction Project\src\clean.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       -0.915025
# 1       -0.915025
# 2       -0.915025
# 3       -0.915025
# 4       -0.915025
#            ...
# 16507   -0.915025
# 16508   -0.915025
# 16509   -0.915025
# 16510   -0.915025
# 16511   -0.915025
# Name: <1h ocean, Length: 16512, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dataset_copy.iloc[:, i] = (dataset_copy.iloc[:, i] - og_mean) / og_std
# c:\Users\PC\Documents\House Prediction Project\src\clean.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0       -0.685512
# 1       -0.685512
# 2       -0.685512
# 3       -0.685512
# 4       -0.685512
#            ...
# 16507    1.458676
# 16508    1.458676
# 16509    1.458676
# 16510    1.458676
# ...
